# %% [markdown]
# https://queimadas.dgi.inpe.br/home/exampleapi

# %%
import os

import pandas as pd
import numpy as np
import netCDF4 as nc

# %%
CSV_URL = 'https://dados_abertos:dados_abertos@queimadas.dgi.inpe.br/queimadas/users/dados_abertos/focos/Diario/focos_abertos_24h_20220827.csv'

# %%
lonW = -73.99 # Longitude Oeste.
lonE = -33.86 # Longitude Leste.
latS = -28.63 # Latitude Sul.
latN = 5.29   # Latitude Norte.
dgrad = .25   # Resolução do píxel.

# %%
df = pd.read_csv("/content/focos_abertos_24h_20220827.csv", parse_dates=['data_hora_gmt'])

# %%
df
# Out:
#                                           id       lat       lon  \
# 0       f6aeae07-338b-312f-af16-ca506d1299aa -27.64000 -61.30000
# 1       11763288-e14d-3b7d-8106-c86916b7c8bf -27.29000 -61.52000
# 2       82f1c0f4-8409-33d7-b6a7-fcece8a85ff9 -26.91000 -60.72000
# 3       16f9393b-0fbc-3325-bb82-0ef3fa7cf7a5 -26.91000 -60.69000
# 4       b86a6222-5850-38c1-a4f8-44362dc500ec -26.69000 -60.99000
# ...                                      ...       ...       ...
# 175952  404dbe30-b609-3893-89d0-e50b205f58b1  63.33243  51.81817
# 175953  d4011ff6-be0d-3559-a7bc-ae3f502a1231  63.31718  51.89207
# 175954  c4d79713-ef58-3b2c-a8b4-86c661a7129e  56.50157  42.40850
# 175955  97ec35c9-4280-3fd3-af67-dfe8338a37e2  55.08256  59.00667
# 175956  6e06c154-10d5-3b41-b606-5f0b5e8eae45  52.22155  51.83440
#
#              data_hora_gmt satelite                      municipio  \
# 0      2022-08-27 00:02:35  GOES-16  Fray Justo Santa María de Oro
# ...

# %%
df.head()
# Out:
#                                      id    lat    lon       data_hora_gmt  \
# 0  f6aeae07-338b-312f-af16-ca506d1299aa -27.64 -61.30 2022-08-27 00:02:35
# 1  11763288-e14d-3b7d-8106-c86916b7c8bf -27.29 -61.52 2022-08-27 00:02:38
# 2  82f1c0f4-8409-33d7-b6a7-fcece8a85ff9 -26.91 -60.72 2022-08-27 00:02:39
# 3  16f9393b-0fbc-3325-bb82-0ef3fa7cf7a5 -26.91 -60.69 2022-08-27 00:02:39
# 4  b86a6222-5850-38c1-a4f8-44362dc500ec -26.69 -60.99 2022-08-27 00:02:40
#
#   satelite                      municipio estado       pais  municipio_id  \
# 0  GOES-16  Fray Justo Santa María de Oro  Chaco  Argentina           176
# 1  GOES-16                Doce de Octubre  Chaco  Argentina           175
# 2  GOES-16                  Independencia  Chaco  Argentina           180
# 3  GOES-16                  Independencia  Chaco  Argentina           180
# 4  GOES-16                  Independencia  Chaco  Argentina           180
#
# ...

# %%
df.describe()
# Out:
#                  lat            lon  municipio_id      estado_id  \
# count  175957.000000  175957.000000  1.759570e+05  175957.000000
# mean       -5.435909       2.371150  5.449465e+05      12.830538
# std        20.258356      57.297642  1.272728e+06      13.295504
# min       -50.743970    -179.324750  1.000000e+00       1.000000
# 25%       -14.876290     -52.921080  2.600000e+01       5.000000
# 50%       -10.915740      18.706920  8.500000e+01       8.000000
# 75%        -5.421660      30.290930  7.430000e+02      15.000000
# max        71.257990     177.769180  5.300108e+06      82.000000
#
#              pais_id  numero_dias_sem_chuva  precipitacao  risco_fogo  \
# count  175957.000000                    0.0           0.0         0.0
# mean       97.141017                    NaN           NaN         NaN
# std        89.542176                    NaN           NaN         NaN
# min         1.000000                    NaN           NaN         NaN
# ...

# %%
lat_col = 'lat'
lon_col = 'lon'
time_col = 'data_hora_gmt'

# %%
filter_ = (df[lat_col] < latN) & (df[lat_col] > latS) & (df[lon_col] < lonE) & (df[lon_col] > lonW)

# %%
focos = df[filter_][[time_col, lat_col, lon_col]].values

# %%
focos.shape
# Out:
# (50078, 3)

# %%
focos
# Out:
# array([[Timestamp('2022-08-27 00:02:35'), -27.64, -61.3],
#        [Timestamp('2022-08-27 00:02:38'), -27.29, -61.52],
#        [Timestamp('2022-08-27 00:02:39'), -26.91, -60.72],
#        ...,
#        [Timestamp('2022-08-27 23:55:07'), -3.34, -50.44],
#        [Timestamp('2022-08-27 23:55:07'), -3.28, -52.62],
#        [Timestamp('2022-08-27 23:55:56'), 3.96, -71.99]], dtype=object)

# %%
units = 'days since 1970-01-01'

# %%
def transform_time(time, units):
    times = pd.Series(time).dt.floor('d').astype(pd.datetime) # Trunca as datas para pegar apenas o dia em questão
    times = nc.date2num(times, units, calendar='standard')
    return times

focos.T[0] = np.apply_along_axis(transform_time, 0, focos.T[0], units)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-6d260fd3169a> in <module>
#       4     return times
#       5
# ----> 6 focos.T[0] = np.apply_along_axis(transform_time, 0, focos.T[0], units)
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     377             'Cannot apply_along_axis when any iteration dimensions are 0'
#     378         ) from None
# --> 379     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     380
#     381     # build a buffer for storing evaluations of func1d.
#
# ...
